# %% [markdown]
# # Crop reallocation algorithm: toy model
# This notebook translates Ishan's Matlab code setting up a toy version of our crop reallocation model into Python
#
# ## Questions for Ishan
# - Confirm that my overall understanding is correct: that the data we're operating on is region-level (IR or geolev1). It seems like maybe we should be operating at the raster pixel level, but then how do we know how much yield is coming from that pixel?
# - Is the way we want to calculate calories actually what’s done in Ishan’s current code? Seems like this assumes calories per acre are uniform across the whole adm1 unit which doesn’t seem right
# - How will we break ties in the min yield planted/max yield empty calculation? This could matter especially if the locations have different climate draws/climate sensitivity
# - How are we incorporating switching costs, again? Is there some condition where we are forcing costs to weakly exceed benefits?
# - discuss correct way to iterate over gamma
# - implementation is slow even with this toy example. For this to be feasible, we're going to need to think about how to speed things up significantly.
#
# ## Things to follow up on
# - Probably want to change data storage so it works with arrays. Will be faster, better able to read projection system outputs, and generally easier to integrate with impact-calculations (need to check all this with James/Brewster)
# - Seems useful to develop a suite of visualizations that helps us understand the steps in the algorithm (and where there's possibility for improvement)
#
# ## Immediate next steps
# - Build in gamma iteration and elasticity iteration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set up parameters
# Here I'm just taking the values from Ishan's code, but attempting to structure them in a way that will work for more data

# %%
# the list of crops we're working with
crops = ['soy', 'rice']

# Initial conditions
yields = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'yield': [10, 20, 15, 20, 10, 15]
})

calories = pd.DataFrame({
    'crop': ['soy', 'rice'],
    'calories': [25, 15]
})

acreage = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'acres_planted': [40, 70, 0, 60, 30, 0],
    'total_acres': [100, 100, 100, 100, 100, 100]
})

# may want to turn the lines that return the merged dataframe into a function that
# standardizes datasets--tbd
present_yields = (yields
          .merge(calories, how='left', on='crop')
          .merge(acreage, how='left', on=['crop', 'geo1_id', 'geo0_id'])
         )
    
present_yields['calorie_yield'] = present_yields['yield'] * present_yields['calories']

# %%
# Climate shocks
# This will eventually be the real projections from the ag sector.
# Before then, we'll use random draws.
# Just use Ishan's numbers for now.

yield_shocks = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'yield_shock': [0.5, 0.8, 1, 0.9, 0.6, 1]
})

future_yields = (yield_shocks
                 .merge(present_yields, how='outer', on=['geo0_id', 'geo1_id', 'crop'])
                )
future_yields['future_yield'] = future_yields['yield'] * future_yields['yield_shock']

# replace the yield column with the future yield column and re-calculate moments
future_yields['yield'] = future_yields['future_yield']
future_yields.drop('future_yield', inplace=True, axis=1)

# %%
present_yields
# Out:
#    geo0_id  geo1_id  crop  yield  calories  acres_planted  total_acres  \
# 0        1        1   soy     10        25             40          100
# 1        1        2   soy     20        25             70          100
# 2        1        3   soy     15        25              0          100
# 3        1        1  rice     20        15             60          100
# 4        1        2  rice     10        15             30          100
# 5        1        3  rice     15        15              0          100
#
#    calorie_yield
# 0            250
# 1            500
# 2            375
# 3            300
# 4            150
# 5            225

# %% [markdown]
# # 2. Set up functions for calculating moments

# %% [markdown]
# ### Moment 1: Gamma

# %%
# update docstring when this is stable
def calculate_gamma(df):
    '''
    Calculate 'gamma', the ratio of total calories produced to possible 
    calories produced.
    
    Parameters:
    -----------
    df: DataFrame
        ***Description here***
        
    '''

    total_cal = sum(df['calorie_yield'] * df['acres_planted'])
    
    # not sure this potential calorie calculation is what we actually want
    potential_cal = (df
        .groupby('geo1_id')
        .agg({'calorie_yield': 'max', 'acres_planted': 'sum'})
    )
    
    potential_cal = sum(potential_cal['calorie_yield'] * potential_cal['acres_planted'])
    
    return  total_cal / potential_cal

# %%
calculate_gamma(present_yields)
# Out:
# 0.84375

# %% [markdown]
# ### Moment 2: Phi

# %%
def analyze_empty_acreage(df, crop):
    '''
    Returns the yield and plot id for the plot with the highest yield that currently has 
    empty space, as well as the yield and plot id for the plot with the lowest yield that 
    is currently occupied.
    These are the conditions that will be calculated in each iteration of the loop in
    `calculate_phi`
    
   Parameters:
    -----------
    df: DataFrame
        ***Description here***
    
    crop: str
        The name of the crop you want to calculate phi for
    
    '''
    # set up initial conditions
    total_acres = (df[['geo0_id', 'geo1_id', 'acres_planted']]
                   .copy()
                   .groupby(['geo0_id', 'geo1_id'])
                   .sum()
                   .rename(columns={'acres_planted':'total_acres_planted'})
        )
    df = df.merge(total_acres, how='left', on=['geo0_id', 'geo1_id'])
    df['empty_acres'] = df['total_acres'] - df['total_acres_planted']

    assert all(df['empty_acres'] >= 0)

    empty_max_yield = max(
        df.loc[
            (df['empty_acres'] > 0) & (df['crop'] == crop), 'yield'
        ]
    )
    empty_max_id = df.loc[
        (df['yield'] == empty_max_yield) & (df['crop'] == crop), ['geo0_id', 'geo1_id']
    ]
    used_min_yield = min(
        df.loc[
            (df['acres_planted'] > 0) & (df['crop'] == crop), 'yield'
        ]
    )
    used_min_id = df.loc[
        (df['yield'] == used_min_yield) & (df['crop'] == crop), ['geo0_id', 'geo1_id']
    ]
 
    return [empty_max_yield, used_min_yield, empty_max_id, used_min_id]

# %%
def reallocate_crops(df, crop, empty_max_yield, used_min_yield, empty_max_id, used_min_id):
    '''
    A loop to reallocate crop area, moving one acre at a time from the lowest-yielding parcel
    of the crop to the highest-yielding unoccupied parcel
    
    Parameters:
    -----------
    df: DataFrame
        ***Description here***
    
    crop: str
        The name of the crop you want to calculate for
        
    cond: bool
        The condition for your while loop
    '''
    df = df.copy()
    
    min_cond = (
        (df['geo0_id'] == used_min_id['geo0_id'].values[0]) &
        (df['geo1_id'] == used_min_id['geo1_id'].values[0]) &
        (df['crop'] == crop)
    )

    val = df.loc[min_cond, 'acres_planted']
    df.loc[min_cond, 'acres_planted'] = val - 1

    # add one acre to the highest-yielding plot that is currently empty
    max_cond = (
        (df['geo0_id'] == empty_max_id['geo0_id'].values[0]) &
        (df['geo1_id'] == empty_max_id['geo1_id'].values[0]) &
        (df['crop'] == crop)
    )
    val = df.loc[max_cond, 'acres_planted']
    df.loc[max_cond, 'acres_planted'] = val + 1
        
    return df

# %%
def calculate_phi(df, crop):
    '''
    Calculate 'phi', the ratio of actual yields to the maximum possible
    yield that would be realized in a perfectly frictionless scenario
    with optimal acreage placement in a country. 
    
    Parameters:
    -----------
    df: DataFrame
        ***Description here***
    
    crop: str
        The name of the crop you want to calculate phi for
    '''

    # don't modify the original data
    df = df.copy()
    
    # calculate actual yields
    data = df[df.crop == crop].copy()
    data['total_yield'] = data['acres_planted'] * data['yield']
    actual_yield = sum(data['total_yield'])
    
    # calculate the potential yield
    # set up initial conditions    
    empty_max_yield, used_min_yield, empty_max_id, used_min_id = (
        analyze_empty_acreage(df, crop)
    )
    
    # reallocate crops from lowest used yield to highest empty yield
    while empty_max_yield > used_min_yield:
        df = reallocate_crops(df, 
                              crop, 
                              empty_max_yield, 
                              used_min_yield, 
                              empty_max_id, 
                              used_min_id)
        
        # recalculate empty acreage
        empty_max_yield, used_min_yield, empty_max_id, used_min_id = (
            analyze_empty_acreage(df, crop)
        )
    
    # calculate potential yields using the reallocated data
    data = df[df.crop == crop].copy()
    data['total_yield'] = data['acres_planted'] * data['yield']
    potential_yield = sum(data['total_yield'])
    
    return actual_yield/potential_yield

# %%
calculate_phi(present_yields, 'soy')
# Out:
# 0.9

# %% [markdown]
# ## Combine the moments calculation into a single function
# Not convinced this step is necessary at this stage. Move on and come back to this if it turns out to be needed.

# %%
# note: try to do this in a crop-agnostic way
def calculate_moments(
    soy_yields,
    rice_yields,
    soy_acreage,
    rice_acreage,
    acreage,
    soy_calories_per_bushel,
    rice_calories_per_bushel
    ):
    
    
    return # want to return gamma and crop-specific phis

# %% [markdown]
# # 3. Write functions that incorporate a climate shock and match moments
#
# Just doing this inline for now, will be functionalized eventually.

# %%
future_yields
# Out:
#    geo0_id  geo1_id  crop  yield_shock  yield  calories  acres_planted  \
# 0        1        1   soy          0.5    5.0        25             40
# 1        1        2   soy          0.8   16.0        25             70
# 2        1        3   soy          1.0   15.0        25              0
# 3        1        1  rice          0.9   18.0        15             60
# 4        1        2  rice          0.6    6.0        15             30
# 5        1        3  rice          1.0   15.0        15              0
#
#    total_acres  calorie_yield
# 0          100            250
# 1          100            500
# 2          100            375
# 3          100            300
# 4          100            150
# 5          100            225

# %%
def calculate_distances(present, future, crops):
    present_moments = [calculate_gamma(present)] + [calculate_phi(present, c) for c in crops]
    future_moments = [calculate_gamma(future)] + [calculate_phi(future, c) for c in crops]

    distances = [p - f for p, f in zip(present_moments, future_moments)]
    return distances

# %%
def match_moments(present, future, crops):
    distances = calculate_distances(present, future, crops)
    while any(d > 0 for d in distances):
        # print(distances)
        if distances[0] > 0:
        # add gamma iteration here
            raise NotImplementedError('gamma iteration not yet implemented')
            
        # reallocate crops simultaneously.
        # note that this means a plot of land could fill up. 
        # will need to tinker with this possibility
        reallocation_info = [analyze_empty_acreage(future, c) for c in crops]
        for i in range(len(crops)):
            if distances[i + 1] > 0:
                future = reallocate_crops(
                    future, 
                    crops[i],
                    reallocation_info[i][0], 
                    reallocation_info[i][1], 
                    reallocation_info[i][2], 
                    reallocation_info[i][3]
                )

            # recalculate distances
            distances = calculate_distances(present, future, crops)
    
    return(future)

# %%
match_moments(present_yields, future_yields, ['soy', 'rice'])
# Out:
#    geo0_id  geo1_id  crop  yield_shock  yield  calories  acres_planted  \
# 0        1        1   soy          0.5    5.0        25             17
# 1        1        2   soy          0.8   16.0        25             87
# 2        1        3   soy          1.0   15.0        25              6
# 3        1        1  rice          0.9   18.0        15             76
# 4        1        2  rice          0.6    6.0        15             13
# 5        1        3  rice          1.0   15.0        15              1
#
#    total_acres  calorie_yield
# 0          100            250
# 1          100            500
# 2          100            375
# 3          100            300
# 4          100            150
# 5          100            225

# %% [markdown]
# ### Do some profiling

# %%
import cProfile
import timeit
from numba import jit

# %%
any([d > 0 for d in distances])

# %%
# creat a numba version to see if it's any faster
@jit
def match_moments_faster(present, future, crops):
    distances = calculate_distances(present, future, crops)
    while any([d > 0 for d in distances]):
        # print(distances)
        if distances[0] > 0:
        # add gamma iteration here
            raise NotImplementedError('gamma iteration not yet implemented')
            
        # reallocate crops simultaneously.
        # note that this means a plot of land could fill up. 
        # will need to tinker with this possibility
        reallocation_info = [analyze_empty_acreage(future, c) for c in crops]
        for i in range(len(crops)):
            if distances[i + 1] > 0:
                future = reallocate_crops(
                    future, 
                    crops[i],
                    reallocation_info[i][0], 
                    reallocation_info[i][1], 
                    reallocation_info[i][2], 
                    reallocation_info[i][3]
                )

            # recalculate distances
            distances = calculate_distances(present, future, crops)
    
    return(future)

# %%
# time the numba and non-numba versions
def wrapper():
    return match_moments(present_yields, future_yields, ['soy', 'rice'])

# %%
def wrapper():
    return match_moments_faster(present_yields, future_yields, ['soy', 'rice'])

timeit.timeit(wrapper, number=1)

# %%
cProfile.run(
    "match_moments(present=present_yields, future=future_yields, crops=['soy', 'rice'])"
)
# Out:
#          246889109 function calls (244530806 primitive calls) in 151.456 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     35250    0.024    0.000    0.222    0.000 <__array_function__ internals>:2(all)
#     11750    0.013    0.000    0.741    0.000 <__array_function__ internals>:2(allclose)
#     11174    0.016    0.000    0.133    0.000 <__array_function__ internals>:2(any)
#     12314    0.011    0.000    0.156    0.000 <__array_function__ internals>:2(append)
#      5781    0.007    0.000    0.049    0.000 <__array_function__ internals>:2(argsort)
#     11174    0.017    0.000    0.179    0.000 <__array_function__ internals>:2(array_equal)
#     23112    0.027    0.000    0.163    0.000 <__array_function__ internals>:2(atleast_2d)
#      6157    0.007    0.000    0.016    0.000 <__array_function__ internals>:2(bincount)
#      5781    0.007    0.000    0.016    0.000 <__array_function__ internals>:2(can_cast)
#     53533    0.053    0.000    0.222    0.000 <__array_function__ internals>:2(concatenate)
#     23406    0.021    0.000    0.072    0.000 <__array_function__ internals>:2(copyto)
#      5781    0.008    0.000    0.219    0.000 <__array_function__ internals>:2(delete)
#     11938    0.012    0.000    0.048    0.000 <__array_function__ internals>:2(empty_like)
#      5781    0.007    0.000    0.172    0.000 <__array_function__ internals>:2(in1d)
#     11750    0.010    0.000    0.619    0.000 <__array_function__ internals>:2(isclose)
#     23488    0.025    0.000    0.051    0.000 <__array_function__ internals>:2(ndim)
#     28705    0.033    0.000    0.481    0.000 <__array_function__ internals>:2(prod)
#     17343    0.015    0.000    0.044    0.000 <__array_function__ internals>:2(putmask)
#     12314    0.010    0.000    0.067    0.000 <__array_function__ internals>:2(ravel)
#     11750    0.011    0.000    0.031    0.000 <__array_function__ internals>:2(result_type)
#      5781    0.009    0.000    0.222    0.000 <__array_function__ internals>:2(setdiff1d)
#     11562    0.012    0.000    0.084    0.000 <__array_function__ internals>:2(sort)
#      5781    0.007    0.000    0.108    0.000 <__array_function__ internals>:2(vstack)
#     11844    0.013    0.000    0.154    0.000 <__array_function__ internals>:2(zeros_like)
#   2011286    0.960    0.000    2.704    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#    283479    0.221    0.000    0.308    0.000 <frozen importlib._bootstrap>:416(parent)
#        94    0.002    0.000    0.330    0.004 <ipython-input-71-ddf57b8d641f>:2(calculate_gamma)
#      5781    0.488    0.000  103.563    0.018 <ipython-input-72-731580b70de2>:1(analyze_empty_acreage)
#      5587    0.230    0.000   46.481    0.008 <ipython-input-73-07b46622c529>:1(reallocate_crops)
#       188    0.284    0.002  149.989    0.798 <ipython-input-74-e74923fa34cd>:1(calculate_phi)
#        47    0.000    0.000  150.325    3.198 <ipython-input-77-3feb855b6c16>:1(calculate_distances)
#        47    0.003    0.000   87.980    1.872 <ipython-input-77-3feb855b6c16>:2(<listcomp>)
#        47    0.003    0.000   62.014    1.319 <ipython-input-77-3feb855b6c16>:3(<listcomp>)
#        47    0.000    0.000    0.000    0.000 <ipython-input-77-3feb855b6c16>:5(<listcomp>)
#         1    0.002    0.002  151.456  151.456 <ipython-input-78-7abf4875c1e0>:1(match_moments)
#        23    0.001    0.000    0.810    0.035 <ipython-input-78-7abf4875c1e0>:12(<listcomp>)
#        73    0.000    0.000    0.000    0.000 <ipython-input-78-7abf4875c1e0>:3(<genexpr>)
#         1    0.000    0.000  151.456  151.456 <string>:1(<module>)
#     57692    0.057    0.000    0.125    0.000 __init__.py:104(_maybe_match_name)
#     34674    0.049    0.000    0.528    0.000 __init__.py:1057(_comp_method_OBJECT_ARRAY)
#     85927    0.529    0.000    4.098    0.000 __init__.py:1081(na_op)
#     85927    0.986    0.000   24.278    0.000 __init__.py:1126(wrapper)
#     45472    0.023    0.000    0.117    0.000 __init__.py:1252(na_op)
#     90944    0.264    0.000   16.619    0.000 __init__.py:1287(<lambda>)
#     45472    0.340    0.000   21.376    0.000 __init__.py:1289(wrapper)
#     45472    0.008    0.000    0.008    0.000 __init__.py:1304(<lambda>)
#     17519    0.025    0.000    0.034    0.000 __init__.py:139(maybe_upcast_for_op)
#    154793    0.125    0.000    0.481    0.000 __init__.py:81(get_op_result_name)
#     62991    0.081    0.000    0.217    0.000 __init__.py:892(_align_method_SERIES)
#     17519    0.045    0.000    2.204    0.000 __init__.py:913(_construct_result)
#     17519    0.082    0.000    0.449    0.000 __init__.py:946(na_op)
#     17519    0.177    0.000    3.983    0.000 __init__.py:974(wrapper)
# 1093627/995774    0.399    0.000    3.494    0.000 _asarray.py:16(asarray)
#     17437    0.080    0.000    0.137    0.000 _asarray.py:223(require)
#     17437    0.020    0.000    0.025    0.000 _asarray.py:300(<setcomp>)
#    140988    0.052    0.000    0.181    0.000 _asarray.py:88(asanyarray)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#        27    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#        90    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
# 52123/34780    0.073    0.000    5.444    0.000 _decorators.py:164(wrapper)
#     11562    0.016    0.000    7.591    0.001 _decorators.py:219(wrapper)
#   1074288    0.653    0.000    2.160    0.000 _dtype.py:319(_name_includes_bit_suffix)
#   1074288    1.884    0.000    4.786    0.000 _dtype.py:333(_name_get)
#   1074288    0.310    0.000    0.310    0.000 _dtype.py:36(_kind_name)
#    195643    0.411    0.000    1.487    0.000 _dtype.py:46(__str__)
#    144971    0.170    0.000    0.170    0.000 _internal.py:830(npy_ctypes_check)
#     17343    0.011    0.000    0.150    0.000 _methods.py:36(_sum)
#    311216    0.128    0.000    1.201    0.000 _methods.py:44(_any)
#     42570    0.018    0.000    0.183    0.000 _methods.py:47(_all)
#    379498    0.530    0.000    0.582    0.000 _ufunc_config.py:139(geterr)
#    379498    0.645    0.000    1.531    0.000 _ufunc_config.py:39(seterr)
#    189749    0.157    0.000    0.202    0.000 _ufunc_config.py:437(__init__)
#    189749    0.175    0.000    1.119    0.000 _ufunc_config.py:441(__enter__)
#    189749    0.175    0.000    0.762    0.000 _ufunc_config.py:446(__exit__)
#      6063    0.008    0.000    0.008    0.000 _validators.py:120(_check_for_invalid_keys)
#      6063    0.011    0.000    0.025    0.000 _validators.py:139(validate_kwargs)
#    193450    0.086    0.000    0.118    0.000 _validators.py:231(validate_bool_kwarg)
#     11562    0.027    0.000    0.045    0.000 _validators.py:241(validate_axis_style_args)
#     90944    0.154    0.000    0.298    0.000 _validators.py:337(validate_fillna_kwargs)
#      6063    0.004    0.000    0.004    0.000 _validators.py:36(_check_for_default_values)
#   1898759    0.537    0.000    1.392    0.000 abc.py:137(__instancecheck__)
#     149/9    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#    187436    0.829    0.000    2.984    0.000 algorithms.py:1481(_get_take_nd_function)
#    187436    1.664    0.000   11.798    0.000 algorithms.py:1608(take_nd)
#     11656    0.036    0.000    1.133    0.000 algorithms.py:167(_reconstruct_data)
#     11656    0.007    0.000    0.046    0.000 algorithms.py:199(_ensure_arraylike)
#     11656    0.018    0.000    0.204    0.000 algorithms.py:253(_get_data_algo)
#     11656    0.041    0.000    0.439    0.000 algorithms.py:483(_factorize_array)
#     23312    0.038    0.000    0.320    0.000 algorithms.py:61(_ensure_data)
#     11656    0.119    0.000    3.281    0.000 algorithms.py:610(factorize)
#        94    0.000    0.000    0.004    0.000 api.py:151(_union_indexes)
#        94    0.000    0.000    0.000    0.000 api.py:228(_sanitize_and_check)
#        94    0.000    0.000    0.000    0.000 api.py:249(<setcomp>)
#    149106    0.100    0.000    0.436    0.000 arrays.py:7(extract_array)
#      5781    0.001    0.000    0.001    0.000 arraysetops.py:480(_in1d_dispatcher)
#      5781    0.095    0.000    0.156    0.000 arraysetops.py:484(in1d)
#      5781    0.002    0.000    0.002    0.000 arraysetops.py:741(_setdiff1d_dispatcher)
#      5781    0.026    0.000    0.203    0.000 arraysetops.py:745(setdiff1d)
#    128004    0.108    0.000    0.609    0.000 base.py:1012(_ndarray_values)
#     11174    0.025    0.000    1.276    0.000 base.py:1093(format)
#     11174    0.053    0.000    1.248    0.000 base.py:1110(_format_with_header)
#      5781    0.015    0.000    0.113    0.000 base.py:1160(tolist)
#     23688    0.089    0.000    0.570    0.000 base.py:1185(__iter__)
#     17343    0.038    0.000    0.113    0.000 base.py:1335(_validate_names)
#     34780    0.024    0.000    0.024    0.000 base.py:1355(_get_names)
#     46342    0.052    0.000    0.109    0.000 base.py:1358(_set_names)
#     46342    0.050    0.000    0.248    0.000 base.py:1390(set_names)
#     46342    0.032    0.000    0.280    0.000 base.py:1470(rename)
#    229910    0.032    0.000    0.032    0.000 base.py:1524(nlevels)
#      5875    0.004    0.000    0.092    0.000 base.py:1725(is_monotonic)
#      5875    0.087    0.000    0.088    0.000 base.py:1732(is_monotonic_increasing)
#   1578238    1.072    0.000    2.007    0.000 base.py:180(construct_from_string)
#     46794    0.200    0.000    0.495    0.000 base.py:1803(is_unique)
#     63685    0.085    0.000    0.705    0.000 base.py:1814(is_boolean)
#     28129    0.024    0.000    0.108    0.000 base.py:1817(is_integer)
#     34674    0.048    0.000    0.152    0.000 base.py:1826(is_object)
#     34298    0.028    0.000    0.035    0.000 base.py:1829(is_categorical)
#     92678    0.048    0.000    0.881    0.000 base.py:1877(inferred_type)
#   4203605    2.893    0.000   12.271    0.000 base.py:231(is_dtype)
#       188    0.000    0.000    0.001    0.000 base.py:231(ndim)
#      5781    0.003    0.000    0.003    0.000 base.py:2326(_get_unique_index)
#      5781    0.015    0.000    3.794    0.001 base.py:235(_obj_with_exclusions)
#        94    0.000    0.000    0.000    0.000 base.py:2403(_get_reconciled_name_object)
#        94    0.000    0.000    0.000    0.000 base.py:2438(_is_compatible_with_other)
#     11750    0.005    0.000    0.005    0.000 base.py:2454(_validate_sort_keyword)
#        94    0.000    0.000    0.003    0.000 base.py:2461(union)
#        94    0.000    0.000    0.001    0.000 base.py:2521(_union)
#      5875    0.093    0.000    1.766    0.000 base.py:2633(intersection)
#      5781    0.087    0.000    0.855    0.000 base.py:2687(difference)
# 197458/173864    2.323    0.000   13.931    0.000 base.py:277(__new__)
#     11750    0.006    0.000    0.031    0.000 base.py:2832(_assert_can_do_setop)
#      5781    0.006    0.000    0.026    0.000 base.py:2837(_convert_can_do_setop)
#    321776    0.243    0.000    6.619    0.000 base.py:2888(get_loc)
#     63685    0.376    0.000    6.331    0.000 base.py:2957(get_indexer)
#     50865    0.080    0.000    0.191    0.000 base.py:3104(_convert_scalar_indexer)
#     17343    0.029    0.000    0.260    0.000 base.py:3228(_convert_listlike_indexer)
#     17343    0.014    0.000    0.222    0.000 base.py:3265(_convert_arr_indexer)
#        94    0.002    0.000    0.240    0.003 base.py:328(_aggregate)
#     17343    0.008    0.000    0.008    0.000 base.py:3305(_convert_list_indexer)
#      5781    0.002    0.000    0.002    0.000 base.py:3347(_can_reindex)
#     23124    0.099    0.000    2.646    0.000 base.py:3364(reindex)
#       188    0.000    0.000    0.000    0.000 base.py:347(<lambda>)
#       282    0.000    0.000    0.000    0.000 base.py:384(<genexpr>)
#    533160    0.301    0.000    0.584    0.000 base.py:3901(values)
#    196536    0.034    0.000    0.034    0.000 base.py:3923(_values)
#    138908    0.055    0.000    0.186    0.000 base.py:4006(_internal_get_values)
#     86021    0.046    0.000    0.056    0.000 base.py:4118(_coerce_to_ndarray)
#      6157    0.019    0.000    1.114    0.000 base.py:4142(_coerce_scalar_to_index)
#    346446    0.430    0.000    0.624    0.000 base.py:4228(__contains__)
#    194216    0.364    0.000    1.801    0.000 base.py:4262(__getitem__)
#     34674    0.037    0.000    0.227    0.000 base.py:4297(_can_hold_identifiers_and_holds_name)
#       188    0.001    0.000    0.150    0.001 base.py:431(_agg_1dim)
#      5781    0.020    0.000    0.856    0.000 base.py:4310(append)
#      5781    0.004    0.000    0.004    0.000 base.py:4334(<setcomp>)
#      5781    0.014    0.000    0.827    0.000 base.py:4339(_concat)
#      5781    0.008    0.000    0.594    0.000 base.py:4347(_concat_same_dtype)
#    196670    0.277    0.000    2.215    0.000 base.py:4377(equals)
#      5781    0.003    0.000    0.124    0.000 base.py:4404(identical)
#        94    0.000    0.000    0.150    0.002 base.py:449(_agg)
#     23124    0.056    0.000    4.002    0.000 base.py:4804(get_indexer_for)
#     63685    0.108    0.000    0.383    0.000 base.py:4821(_maybe_promote)
#     17331    0.010    0.000    0.014    0.000 base.py:5044(_maybe_cast_indexer)
#        94    0.000    0.000    0.001    0.000 base.py:519(is_any_frame)
#       282    0.000    0.000    0.000    0.000 base.py:521(<genexpr>)
#     35626    0.013    0.000    0.015    0.000 base.py:526(<genexpr>)
#      5781    0.014    0.000    0.300    0.000 base.py:5285(delete)
#      6157    0.036    0.000    1.764    0.000 base.py:5295(insert)
#      5781    0.046    0.000    1.111    0.000 base.py:5315(drop)
#    318541    0.760    0.000    1.590    0.000 base.py:569(_simple_new)
#    846667    0.462    0.000    5.549    0.000 base.py:5707(ensure_index)
#     23124    0.011    0.000    0.019    0.000 base.py:5774(_ensure_has_len)
#     11174    0.031    0.000    0.087    0.000 base.py:5786(_trim_front)
#    100566    0.022    0.000    0.022    0.000 base.py:5791(<genexpr>)
#     11174    0.012    0.000    0.012    0.000 base.py:5792(<listcomp>)
#      5781    0.018    0.000    0.096    0.000 base.py:5801(default_index)
#    225963    0.182    0.000    0.371    0.000 base.py:613(_get_attributes_dict)
#    225963    0.143    0.000    0.189    0.000 base.py:617(<dictcomp>)
#    144677    0.400    0.000    1.665    0.000 base.py:634(_shallow_copy)
#     69348    0.192    0.000    4.814    0.000 base.py:652(_shallow_copy_with_infer)
#    196670    0.121    0.000    0.152    0.000 base.py:681(is_)
#    330103    0.148    0.000    0.148    0.000 base.py:700(_reset_identity)
#     58162    0.117    0.000    0.486    0.000 base.py:710(_engine)
#     58350    0.009    0.000    0.009    0.000 base.py:717(<lambda>)
#    114244    0.020    0.000    0.020    0.000 base.py:717(ndim)
#   1611749    0.561    0.000    0.742    0.000 base.py:723(__len__)
#      6157    0.005    0.000    0.009    0.000 base.py:729(__array__)
#    168647    0.055    0.000    0.055    0.000 base.py:747(dtype)
#     52381    0.068    0.000    0.777    0.000 base.py:784(view)
#      5781    0.005    0.000    0.008    0.000 base.py:794(size)
#     45848    0.177    0.000    0.999    0.000 base.py:831(array)
#     52029    0.020    0.000    0.051    0.000 base.py:87(_reset_cache)
#     57892    0.158    0.000    3.032    0.000 base.py:885(take)
#     23218    0.019    0.000    0.047    0.000 base.py:905(_assert_take_fillable)
#     85927    0.156    0.000    0.740    0.000 base.py:916(to_numpy)
#    659401    1.229    0.000    2.563    0.000 blocks.py:120(__init__)
#     51982    0.196    0.000    3.589    0.000 blocks.py:1293(take_nd)
#    659401    0.254    0.000    0.254    0.000 blocks.py:131(_check_ndim)
#     62604    0.098    0.000    0.354    0.000 blocks.py:170(_consolidate_key)
#     90944    0.060    0.000    0.919    0.000 blocks.py:188(is_categorical_astype)
#    130999    0.022    0.000    0.022    0.000 blocks.py:203(external_values)
#    295569    0.051    0.000    0.051    0.000 blocks.py:207(internal_values)
#     11174    0.006    0.000    0.008    0.000 blocks.py:213(formatting_values)
#     25521    0.014    0.000    0.061    0.000 blocks.py:217(get_values)
#     22348    0.045    0.000    0.070    0.000 blocks.py:2178(_can_hold_element)
#     11174    0.013    0.000    0.081    0.000 blocks.py:2188(should_store)
#     69325    0.026    0.000    0.026    0.000 blocks.py:235(fill_value)
#   1352354    0.225    0.000    0.225    0.000 blocks.py:239(mgr_locs)
#    670963    0.594    0.000    0.807    0.000 blocks.py:243(mgr_locs)
#     16955    0.022    0.000    0.615    0.000 blocks.py:257(make_block)
#    433051    0.476    0.000    3.344    0.000 blocks.py:267(make_block_same_class)
#     46982    0.071    0.000    0.247    0.000 blocks.py:2788(__init__)
#      5781    0.009    0.000    0.023    0.000 blocks.py:2794(is_bool)
#     25521    0.011    0.000    0.014    0.000 blocks.py:304(__len__)
#    226538    0.851    0.000    5.413    0.000 blocks.py:3212(get_block_type)
#    659401    1.298    0.000   10.049    0.000 blocks.py:3258(make_block)
#    262263    0.458    0.000    0.942    0.000 blocks.py:3290(_extend_blocks)
#     13959    0.077    0.000    0.622    0.000 blocks.py:3322(_merge_blocks)
#      5781    0.046    0.000    0.049    0.000 blocks.py:3336(<listcomp>)
#      5781    0.003    0.000    0.003    0.000 blocks.py:3337(<listcomp>)
#    114680    0.031    0.000    0.031    0.000 blocks.py:339(shape)
#   1713600    0.356    0.000    0.356    0.000 blocks.py:343(dtype)
#    195643    0.197    0.000    2.380    0.000 blocks.py:347(ftype)
#    138158    0.115    0.000    0.115    0.000 blocks.py:369(iget)
#     11174    0.067    0.000    0.067    0.000 blocks.py:372(set)
#     90944    0.157    0.000    3.726    0.000 blocks.py:400(fillna)
#     90944    0.117    0.000    2.867    0.000 blocks.py:558(astype)
#     90944    0.313    0.000    2.750    0.000 blocks.py:561(_astype)
#      6063    0.005    0.000    0.069    0.000 blocks.py:674(convert)
#     16955    0.024    0.000    1.711    0.000 blocks.py:690(_try_cast_result)
#     11174    0.002    0.000    0.002    0.000 blocks.py:712(_coerce_values)
#     11174    0.033    0.000    0.592    0.000 blocks.py:726(_try_coerce_args)
#     16955    0.003    0.000    0.003    0.000 blocks.py:741(_try_coerce_result)
#     16955    0.023    0.000    1.738    0.000 blocks.py:745(_try_coerce_and_cast_result)
#    242911    0.300    0.000    2.461    0.000 blocks.py:767(copy)
#     11174    0.094    0.000    1.543    0.000 blocks.py:840(setitem)
#     11750    0.002    0.000    0.002    0.000 cast.py:101(trans)
#     41031    0.119    0.000    0.274    0.000 cast.py:1239(construct_1d_object_array_from_listlike)
#    103446    0.084    0.000    0.213    0.000 cast.py:1264(construct_1d_ndarray_preserving_na)
#    146969    0.806    0.000    2.626    0.000 cast.py:298(maybe_promote)
#     22348    0.010    0.000    0.014    0.000 cast.py:515(maybe_infer_dtype_type)
#     46248    0.031    0.000    0.113    0.000 cast.py:583(coerce_indexer_dtype)
#    149106    0.587    0.000    1.106    0.000 cast.py:866(maybe_castable)
#     17519    0.035    0.000    0.204    0.000 cast.py:880(maybe_infer_to_datetimelike)
#     17143    0.122    0.000    1.714    0.000 cast.py:93(maybe_downcast_to_dtype)
#    103446    0.393    0.000    1.780    0.000 cast.py:986(maybe_cast_to_datetime)
#    197176    0.163    0.000    0.523    0.000 common.py:1006(is_signed_integer_dtype)
#     87843    0.063    0.000    0.155    0.000 common.py:1063(is_unsigned_integer_dtype)
#    227397    0.159    0.000    1.839    0.000 common.py:1163(is_datetime64_any_dtype)
#     45848    0.046    0.000    0.088    0.000 common.py:1203(is_datetime64_ns_dtype)
#     45848    0.028    0.000    0.084    0.000 common.py:1253(is_timedelta64_ns_dtype)
#     45848    0.010    0.000    0.010    0.000 common.py:1281(<lambda>)
#    320689    0.307    0.000    0.995    0.000 common.py:1284(is_datetime_or_timedelta_dtype)
#     62427    0.100    0.000    1.561    0.000 common.py:1407(is_datetimelike_v_numeric)
#      5969    0.004    0.000    0.023    0.000 common.py:144(ensure_int_or_float)
#    320689    0.284    0.000    3.409    0.000 common.py:1466(needs_i8_conversion)
#    171868    0.085    0.000    0.114    0.000 common.py:150(cast_scalar_indexer)
#     40843    0.039    0.000    0.109    0.000 common.py:1510(is_numeric_dtype)
#      5781    0.003    0.000    0.012    0.000 common.py:1553(is_string_like_dtype)
#      5781    0.003    0.000    0.003    0.000 common.py:1582(<lambda>)
#    253117    0.208    0.000    0.526    0.000 common.py:1585(is_float_dtype)
#    244082    0.313    0.000    1.816    0.000 common.py:1619(is_bool_dtype)
#    138108    0.128    0.000    1.539    0.000 common.py:1684(is_extension_type)
#   2454408    1.985    0.000    6.772    0.000 common.py:1743(is_extension_array_dtype)
#     33522    0.022    0.000    0.071    0.000 common.py:1792(is_complex_dtype)
#     11562    0.009    0.000    0.011    0.000 common.py:180(ensure_python_int)
#    207197    0.140    0.000    0.398    0.000 common.py:1825(_is_dtype)
#      5781    0.003    0.000    0.003    0.000 common.py:185(_all_none)
#   1116489    0.533    0.000    1.085    0.000 common.py:1850(_get_dtype)
#   2964786    2.710    0.000    6.309    0.000 common.py:1886(_is_dtype_type)
#     11562    0.004    0.000    0.004    0.000 common.py:195(_any_not_none)
#   1630701    1.503    0.000    4.581    0.000 common.py:2020(pandas_dtype)
#   2346199    0.472    0.000    0.472    0.000 common.py:209(classes)
#   2346199    0.559    0.000    0.877    0.000 common.py:211(<lambda>)
#    618587    0.125    0.000    0.125    0.000 common.py:214(classes_and_not_datetimelike)
#     11562    0.012    0.000    0.033    0.000 common.py:215(count_not_none)
#     34686    0.007    0.000    0.007    0.000 common.py:219(<genexpr>)
#    618587    0.259    0.000    0.367    0.000 common.py:219(<lambda>)
#    612335    0.483    0.000    1.655    0.000 common.py:225(is_object_dtype)
#        94    0.000    0.000    0.000    0.000 common.py:230(dict_keys_to_ordered_list)
#    134561    0.320    0.000    1.177    0.000 common.py:240(asarray_tuplesafe)
#    643379    0.912    0.000    2.034    0.000 common.py:255(is_sparse)
#      5781    0.014    0.000    0.062    0.000 common.py:264(index_labels_to_array)
#     23124    0.010    0.000    0.013    0.000 common.py:291(maybe_make_list)
#       188    0.000    0.000    0.001    0.000 common.py:297(maybe_iterable_to_list)
#     68208    0.030    0.000    0.039    0.000 common.py:306(is_null_slice)
#    338173    0.123    0.000    0.167    0.000 common.py:352(apply_if_callable)
#    364646    0.210    0.000    1.732    0.000 common.py:357(is_categorical)
#      5781    0.007    0.000    0.019    0.000 common.py:486(_get_rename_function)
#      5781    0.003    0.000    0.003    0.000 common.py:493(f)
#    597472    0.545    0.000    2.542    0.000 common.py:508(is_datetime64_dtype)
#   1787681    0.798    0.000    5.637    0.000 common.py:539(is_datetime64tz_dtype)
#    529064    0.396    0.000    2.020    0.000 common.py:577(is_timedelta64_dtype)
#    785528    0.366    0.000    2.896    0.000 common.py:608(is_period_dtype)
#    808890    0.356    0.000    2.615    0.000 common.py:642(is_interval_dtype)
#   1203450    0.737    0.000    4.801    0.000 common.py:678(is_categorical_dtype)
#    155568    0.077    0.000    0.410    0.000 common.py:711(is_string_dtype)
#    155568    0.077    0.000    0.100    0.000 common.py:741(condition)
#     29469    0.037    0.000    0.408    0.000 common.py:814(is_datetimelike)
#    321337    0.229    0.000    0.562    0.000 common.py:862(is_dtype_equal)
#    292725    0.253    0.000    0.789    0.000 common.py:951(is_integer_dtype)
#    194602    0.424    0.000    2.029    0.000 common.py:99(is_bool_indexer)
#     25521    0.014    0.000    0.014    0.000 concat.py:117(__init__)
#     25521    0.121    0.000    0.270    0.000 concat.py:130(needs_filling)
#     25521    0.031    0.000    0.311    0.000 concat.py:139(dtype)
#     25521    0.053    0.000    0.435    0.000 concat.py:149(is_na)
#     25521    0.141    0.000    2.669    0.000 concat.py:177(get_reindexed_values)
#     25521    0.079    0.000    4.311    0.000 concat.py:241(concatenate_join_units)
#     25521    0.026    0.000    2.694    0.000 concat.py:252(<listcomp>)
#     25521    0.330    0.000    1.510    0.000 concat.py:273(get_empty_dtype_and_na)
#     11562    0.172    0.000    0.316    0.000 concat.py:28(get_mgr_concatenation_plan)
#      5781    0.035    0.000    0.218    0.000 concat.py:33(get_dtype_kinds)
#     25521    0.060    0.000    0.627    0.000 concat.py:379(is_uniform_join_units)
#     51042    0.020    0.000    0.020    0.000 concat.py:388(<genexpr>)
#     51042    0.053    0.000    0.489    0.000 concat.py:392(<genexpr>)
#     51042    0.013    0.000    0.013    0.000 concat.py:395(<genexpr>)
#     25521    0.021    0.000    0.072    0.000 concat.py:402(is_uniform_reindex)
#     51042    0.030    0.000    0.044    0.000 concat.py:405(<genexpr>)
#     31302    0.032    0.000    0.048    0.000 concat.py:438(combine_concat_plans)
#      5781    0.038    0.000    0.586    0.000 concat.py:497(_concat_index_asobject)
#      5781    0.005    0.000    0.028    0.000 concat.py:506(<listcomp>)
#      5781    0.007    0.000    0.010    0.000 concat.py:512(<listcomp>)
#    245828    0.170    0.000    1.102    0.000 config.py:101(_get_option)
#    245828    0.094    0.000    1.196    0.000 config.py:232(__call__)
#    245828    0.066    0.000    0.066    0.000 config.py:535(_select_options)
#    245828    0.167    0.000    0.231    0.000 config.py:553(_get_root)
#    491656    0.177    0.000    0.177    0.000 config.py:568(_get_deprecated_option)
#    245828    0.063    0.000    0.132    0.000 config.py:596(_translate_key)
#    245828    0.074    0.000    0.182    0.000 config.py:609(_warn_if_deprecated)
#    245828    0.283    0.000    0.701    0.000 config.py:83(_get_single_key)
#        94    0.001    0.000    0.047    0.000 construction.py:216(init_dict)
#       282    0.000    0.000    0.001    0.000 construction.py:248(<genexpr>)
#        94    0.000    0.000    0.001    0.000 construction.py:252(<listcomp>)
#        94    0.000    0.000    0.001    0.000 construction.py:255(<listcomp>)
#        94    0.000    0.000    0.000    0.000 construction.py:300(_homogenize)
#        94    0.000    0.000    0.005    0.000 construction.py:331(extract_index)
#    149106    0.715    0.000    7.560    0.000 construction.py:630(sanitize_array)
#        94    0.000    0.000    0.029    0.000 construction.py:69(arrays_to_mgr)
#    149106    0.358    0.000    4.998    0.000 construction.py:759(_try_cast)
#      5781    0.007    0.000    0.010    0.000 copy.py:66(copy)
#    179163    0.217    0.000    0.361    0.000 dtypes.py:1040(construct_from_string)
#    623746    0.637    0.000    2.258    0.000 dtypes.py:1092(is_dtype)
#    243224    0.261    0.000    0.510    0.000 dtypes.py:717(construct_from_string)
#   2654109    2.895    0.000    6.512    0.000 dtypes.py:83(find)
#    179163    0.201    0.000    0.462    0.000 dtypes.py:866(construct_from_string)
#    785528    0.616    0.000    2.530    0.000 dtypes.py:912(is_dtype)
#     17519    0.017    0.000    0.033    0.000 expressions.py:172(_has_bool_dtype)
#     17519    0.020    0.000    0.052    0.000 expressions.py:182(_bool_arith_check)
#     17519    0.027    0.000    0.347    0.000 expressions.py:206(evaluate)
#     17519    0.054    0.000    0.267    0.000 expressions.py:65(_evaluate_standard)
#     22348    0.031    0.000    0.031    0.000 format.py:1037(__init__)
#     22348    0.049    0.000    2.811    0.000 format.py:1063(get_result)
#     11174    0.183    0.000    1.800    0.000 format.py:1067(_format_strings)
#     67044    0.041    0.000    0.443    0.000 format.py:1081(<lambda>)
#     67044    0.092    0.000    0.654    0.000 format.py:1084(_format)
#     11174    0.017    0.000    0.167    0.000 format.py:1293(_format_strings)
#     67044    0.021    0.000    0.090    0.000 format.py:1294(<lambda>)
#     11174    0.059    0.000    0.149    0.000 format.py:1295(<listcomp>)
#     22348    0.081    0.000    0.796    0.000 format.py:1555(_make_fixed_width)
#    156436    0.045    0.000    0.085    0.000 format.py:1563(<genexpr>)
#    134088    0.047    0.000    0.082    0.000 format.py:1572(just)
#     22348    0.032    0.000    0.114    0.000 format.py:1578(<listcomp>)
#     11174    0.053    0.000    0.318    0.000 format.py:189(__init__)
#     11174    0.032    0.000    0.091    0.000 format.py:221(_chk_truncate)
#     11174    0.059    0.000    0.302    0.000 format.py:247(_get_footer)
#     11174    0.022    0.000    1.308    0.000 format.py:285(_get_formatted_index)
#     11174    0.020    0.000    2.692    0.000 format.py:297(_get_formatted_values)
#     11174    0.063    0.000    4.763    0.000 format.py:303(to_string)
#     33522    0.024    0.000    0.169    0.000 format.py:344(__init__)
#    335220    0.066    0.000    0.092    0.000 format.py:347(len)
#     44696    0.028    0.000    0.163    0.000 format.py:350(justify)
#     11174    0.033    0.000    0.334    0.000 format.py:353(adjoin)
#     33522    0.046    0.000    0.403    0.000 format.py:394(_get_adjustment)
#     22348    0.136    0.000    3.631    0.000 format.py:959(format_array)
#    207162    0.860    0.000   13.070    0.000 frame.py:2964(__getitem__)
#       376    0.002    0.000    0.195    0.001 frame.py:3019(_getitem_bool_array)
#    138158    0.265    0.000    2.559    0.000 frame.py:3459(_box_item_values)
#    138158    0.227    0.000    1.732    0.000 frame.py:3466(_box_col_values)
#     17331    0.065    0.000    4.491    0.000 frame.py:3473(__setitem__)
#     17331    0.012    0.000    0.029    0.000 frame.py:3532(_ensure_valid_index)
#     17331    0.062    0.000    4.335    0.000 frame.py:3552(_set_item)
#     17331    0.087    0.000    0.609    0.000 frame.py:3683(_sanitize_column)
#     17331    0.035    0.000    0.117    0.000 frame.py:3703(reindexer)
#     70212    0.021    0.000    0.021    0.000 frame.py:380(_constructor)
#      5781    0.021    0.000    2.195    0.000 frame.py:3852(_reindex_axes)
#      5781    0.020    0.000    2.174    0.000 frame.py:3889(_reindex_columns)
#      5781    0.022    0.000    2.554    0.000 frame.py:3957(reindex)
#     76087    0.248    0.000    0.541    0.000 frame.py:397(__init__)
#      5781    0.012    0.000    3.778    0.001 frame.py:3978(drop)
#      5781    0.036    0.000    5.021    0.001 frame.py:4120(rename)
#      5781    0.032    0.000    0.300    0.000 frame.py:4479(reset_index)
#      5781    0.010    0.000    0.071    0.000 frame.py:4670(<listcomp>)
#    246737    0.126    0.000    0.126    0.000 frame.py:491(axes)
#      5781    0.049    0.000   19.041    0.003 frame.py:7317(merge)
#     34674    0.025    0.000    0.069    0.000 frame.py:992(__len__)
#     12314    0.002    0.000    0.002    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     12314    0.016    0.000    0.048    0.000 fromnumeric.py:1693(ravel)
#     11174    0.003    0.000    0.003    0.000 fromnumeric.py:2232(_any_dispatcher)
#     11174    0.017    0.000    0.103    0.000 fromnumeric.py:2236(any)
#     35250    0.005    0.000    0.005    0.000 fromnumeric.py:2320(_all_dispatcher)
#     35250    0.028    0.000    0.175    0.000 fromnumeric.py:2324(all)
#     28705    0.006    0.000    0.006    0.000 fromnumeric.py:2838(_prod_dispatcher)
#     28705    0.047    0.000    0.414    0.000 fromnumeric.py:2843(prod)
#     23488    0.005    0.000    0.005    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#     23488    0.007    0.000    0.007    0.000 fromnumeric.py:3037(ndim)
#      5781    0.006    0.000    0.030    0.000 fromnumeric.py:55(_wrapfunc)
#     75129    0.164    0.000    0.599    0.000 fromnumeric.py:73(_wrapreduction)
#     75129    0.043    0.000    0.043    0.000 fromnumeric.py:74(<dictcomp>)
#     11562    0.003    0.000    0.003    0.000 fromnumeric.py:833(_sort_dispatcher)
#     11562    0.019    0.000    0.062    0.000 fromnumeric.py:837(sort)
#      5781    0.002    0.000    0.002    0.000 fromnumeric.py:993(_argsort_dispatcher)
#      5781    0.007    0.000    0.037    0.000 fromnumeric.py:997(argsort)
#     46248    0.016    0.000    0.034    0.000 frozen.py:146(_shallow_copy)
#     46248    0.041    0.000    0.183    0.000 frozen.py:188(_ensure_frozen)
#    150306    0.149    0.000    0.194    0.000 frozen.py:78(__getitem__)
#     40455    0.017    0.000    0.017    0.000 function.py:42(__call__)
#     11174    0.007    0.000    0.010    0.000 function_base.py:257(iterable)
#      5781    0.002    0.000    0.002    0.000 function_base.py:4214(_delete_dispatcher)
#      5781    0.104    0.000    0.202    0.000 function_base.py:4218(delete)
#     12314    0.003    0.000    0.003    0.000 function_base.py:4636(_append_dispatcher)
#     12314    0.025    0.000    0.133    0.000 function_base.py:4640(append)
#      5781    0.092    0.000    4.958    0.001 generic.py:1014(rename)
#      5781    0.040    0.000   15.241    0.003 generic.py:126(_cython_agg_general)
#      5781    0.099    0.000   14.100    0.002 generic.py:134(_cython_agg_blocks)
#        94    0.000    0.000    0.251    0.003 generic.py:1446(aggregate)
#       188    0.001    0.000    0.005    0.000 generic.py:1459(_gotitem)
#      5781    0.026    0.000    3.824    0.001 generic.py:1502(_get_data_to_aggregate)
#      5781    0.035    0.000    1.101    0.000 generic.py:1548(_wrap_agged_blocks)
#     57810    0.125    0.000    0.602    0.000 generic.py:1599(_is_level_reference)
#    579337    0.823    0.000    0.823    0.000 generic.py:162(__init__)
#     69372    0.131    0.000    0.553    0.000 generic.py:1629(_is_label_reference)
#    138744    0.028    0.000    0.028    0.000 generic.py:1650(<genexpr>)
#    138744    0.099    0.000    0.303    0.000 generic.py:1655(<genexpr>)
#     11562    0.006    0.000    0.155    0.000 generic.py:1658(_is_label_or_level_reference)
#     23218    0.076    0.000    0.141    0.000 generic.py:1682(_check_label_or_level_ambiguity)
#     23218    0.005    0.000    0.005    0.000 generic.py:1701(<genexpr>)
#     23124    0.137    0.000    3.420    0.000 generic.py:1731(_get_label_or_level_values)
#     23124    0.012    0.000    0.012    0.000 generic.py:1766(<listcomp>)
#        94    0.000    0.000    0.001    0.000 generic.py:1791(_maybe_mangle_lambdas)
#      5781    0.031    0.000    1.946    0.000 generic.py:1803(_drop_labels_or_levels)
#      5781    0.008    0.000    0.163    0.000 generic.py:1834(<listcomp>)
#      5781    0.006    0.000    0.125    0.000 generic.py:1846(<listcomp>)
#      5781    0.005    0.000    0.118    0.000 generic.py:1848(<listcomp>)
#     75993    0.077    0.000    0.091    0.000 generic.py:185(_init_mgr)
#       376    0.001    0.000    0.001    0.000 generic.py:1883(__hash__)
#     34874    0.033    0.000    0.274    0.000 generic.py:1934(__contains__)
#        94    0.001    0.000    0.250    0.003 generic.py:215(aggregate)
#     85927    0.059    0.000    2.770    0.000 generic.py:227(_validate_dtype)
#    201005    0.422    0.000    6.577    0.000 generic.py:3265(_get_item_cache)
#    138158    0.123    0.000    0.314    0.000 generic.py:3279(_set_as_cached)
#     11174    0.021    0.000    0.064    0.000 generic.py:3324(_maybe_update_cacher)
#     45848    0.035    0.000    0.127    0.000 generic.py:3358(_clear_item_cache)
#     17331    0.063    0.000    3.589    0.000 generic.py:3380(_set_item)
#     17719    0.023    0.000    0.039    0.000 generic.py:3384(_set_is_copy)
#     28505    0.012    0.000    0.012    0.000 generic.py:3413(_check_setitem_copy)
#     11562    0.045    0.000    0.071    0.000 generic.py:346(_construct_axes_from_arguments)
#     17719    0.174    0.000   10.081    0.001 generic.py:3524(take)
#     34298    0.056    0.000    2.027    0.000 generic.py:3615(xs)
#     11562    0.010    0.000    0.014    0.000 generic.py:385(<dictcomp>)
#      5781    0.019    0.000    3.766    0.001 generic.py:3883(drop)
#      5781    0.038    0.000    3.733    0.001 generic.py:3921(_drop_axis)
#    380452    0.336    0.000    0.466    0.000 generic.py:400(_get_axis_number)
#    486023    0.385    0.000    0.525    0.000 generic.py:413(_get_axis_name)
#    462899    0.287    0.000    0.929    0.000 generic.py:426(_get_axis)
#      5781    0.047    0.000    2.507    0.000 generic.py:4266(reindex)
#     40843    0.039    0.000    0.093    0.000 generic.py:430(_get_block_manager_axis)
#     11562    0.013    0.000    0.149    0.000 generic.py:4497(<genexpr>)
#      5781    0.012    0.000    0.030    0.000 generic.py:4540(_needs_reindex_multi)
#     17343    0.127    0.000    5.353    0.000 generic.py:4552(_reindex_with_indexers)
#     75329    0.036    0.000    0.064    0.000 generic.py:486(_info_axis)
#    147978    0.089    0.000    0.165    0.000 generic.py:510(ndim)
#    315279    0.373    0.000    0.756    0.000 generic.py:5145(__finalize__)
# 640794/640418    0.695    0.000    0.975    0.000 generic.py:5162(__getattr__)
#    975002    1.557    0.000    3.116    0.000 generic.py:5181(__setattr__)
#    148636    0.189    0.000    3.091    0.000 generic.py:5236(_protect_consolidate)
#    137462    0.099    0.000    3.139    0.000 generic.py:5246(_consolidate_inplace)
#    137462    0.131    0.000    2.806    0.000 generic.py:5249(f)
#     11174    0.010    0.000    0.061    0.000 generic.py:5276(_is_mixed_type)
#     11174    0.011    0.000    0.033    0.000 generic.py:5278(<lambda>)
#     90944    0.403    0.000    6.754    0.000 generic.py:5742(astype)
#     34668    0.115    0.000    4.825    0.000 generic.py:5891(copy)
#      6063    0.026    0.000    0.545    0.000 generic.py:6013(_convert)
#     90944    0.746    0.000    9.354    0.000 generic.py:6101(fillna)
#      5781    0.010    0.000    0.056    0.000 generic.py:689(_set_axis)
#  18679251    5.013    0.000    6.973    0.000 generic.py:7(_check)
#       564    0.000    0.000    0.000    0.000 generic.py:746(_selection_name)
#      5875    0.038    0.000    1.660    0.000 generic.py:7758(groupby)
#       188    0.000    0.000    0.142    0.001 generic.py:817(aggregate)
#       188    0.001    0.000    0.025    0.000 generic.py:939(_wrap_output)
#       188    0.001    0.000    0.035    0.000 generic.py:951(_wrap_aggregated_output)
#      5969    0.026    0.000   17.394    0.003 groupby.py:1357(f)
#      5969    0.014    0.000    0.032    0.000 groupby.py:2429(_reindex_output)
#     17343    0.008    0.000    0.011    0.000 groupby.py:2464(<genexpr>)
#      5875    0.023    0.000    1.603    0.000 groupby.py:2509(groupby)
#      6063    0.063    0.000    1.573    0.000 groupby.py:343(__init__)
#       282    0.000    0.000    0.000    0.000 groupby.py:493(_selected_obj)
#      5969    0.053    0.000    1.987    0.000 groupby.py:515(_set_group_selection)
#      5781    0.005    0.000    0.005    0.000 groupby.py:533(<listcomp>)
#     11938    0.015    0.000    0.016    0.000 groupby.py:557(__getattr__)
#        94    0.000    0.000    0.000    0.000 groupby.py:596(_make_wrapper)
#       376    0.000    0.000    0.000    0.000 groupby.py:748(_iterate_slices)
#       188    0.001    0.000    0.029    0.000 groupby.py:786(_try_cast)
#       188    0.002    0.000    0.141    0.001 groupby.py:872(_cython_agg_general)
#     11656    0.066    0.000    0.270    0.000 grouper.py:245(__init__)
#     23124    0.015    0.000    0.041    0.000 grouper.py:381(ngroups)
#     11750    0.012    0.000    4.014    0.000 grouper.py:394(labels)
#     11656    0.006    0.000    0.043    0.000 grouper.py:400(result_index)
#     34874    0.010    0.000    0.044    0.000 grouper.py:408(group_index)
#     11656    0.055    0.000    4.036    0.000 grouper.py:414(_make_labels)
#      5875    0.141    0.000    1.441    0.000 grouper.py:431(_get_grouper)
#     17531    0.008    0.000    0.010    0.000 grouper.py:555(<genexpr>)
#     17531    0.005    0.000    0.006    0.000 grouper.py:556(<genexpr>)
#     17531    0.008    0.000    0.011    0.000 grouper.py:558(<genexpr>)
#     11656    0.006    0.000    0.012    0.000 grouper.py:590(is_in_axis)
#     11656    0.020    0.000    0.022    0.000 grouper.py:600(is_in_obj)
#     11656    0.005    0.000    0.006    0.000 grouper.py:668(_is_label_like)
#     11656    0.021    0.000    0.057    0.000 grouper.py:672(_convert_grouper)
#      6157    0.100    0.000    0.269    0.000 index_tricks.py:318(__getitem__)
#    233917    0.121    0.000    0.424    0.000 indexers.py:13(is_list_like_indexer)
#     17719    0.137    0.000    0.275    0.000 indexers.py:161(maybe_convert_indices)
#     11174    0.014    0.000    0.033    0.000 indexers.py:209(length_of_indexer)
#     11174    0.011    0.000    0.029    0.000 indexers.py:29(is_scalar_indexer)
#     22348    0.008    0.000    0.010    0.000 indexers.py:35(<genexpr>)
#     11174    0.025    0.000    0.060    0.000 indexers.py:39(is_empty_indexer)
#     22348    0.010    0.000    0.012    0.000 indexers.py:57(<genexpr>)
#     11174    0.015    0.000    0.035    0.000 indexers.py:65(check_setitem_lengths)
#     17343    0.146    0.000    5.788    0.000 indexing.py:1042(_get_listlike_indexer)
#     11562    0.059    0.000    7.658    0.001 indexing.py:1096(_getitem_iterable)
#     17343    0.100    0.000    0.322    0.000 indexing.py:1138(_validate_read_indexer)
#     28129    0.166    0.000    9.520    0.000 indexing.py:1205(_convert_to_indexer)
# 57034/34298    0.155    0.000   26.022    0.001 indexing.py:1410(__getitem__)
#    102894    0.061    0.000    0.094    0.000 indexing.py:1412(<genexpr>)
#     34298    0.098    0.000   12.679    0.000 indexing.py:1435(_getbool_axis)
#     22736    0.033    0.000    1.343    0.000 indexing.py:150(_get_label)
#     11174    0.029    0.000    7.498    0.001 indexing.py:168(_get_setitem_indexer)
#     57422    0.078    0.000    0.821    0.000 indexing.py:1710(_validate_key)
#     34298    0.086    0.000    0.241    0.000 indexing.py:1727(_is_scalar_access)
#     68596    0.026    0.000    0.037    0.000 indexing.py:1759(_get_partial_string_timestamp_match_key)
#     68596    0.320    0.000   23.804    0.000 indexing.py:1787(_getitem_axis)
#     11174    0.062    0.000   15.863    0.001 indexing.py:199(__setitem__)
#     33522    0.020    0.000    0.030    0.000 indexing.py:201(<genexpr>)
#     11562    0.029    0.000    0.419    0.000 indexing.py:229(_has_valid_tuple)
#     23488    0.043    0.000    0.081    0.000 indexing.py:2352(convert_to_index_sliceable)
#     45848    0.131    0.000    2.312    0.000 indexing.py:2377(check_bool_indexer)
#     34298    0.051    0.000    0.152    0.000 indexing.py:242(_is_nested_tuple_indexer)
#    102894    0.032    0.000    0.046    0.000 indexing.py:243(<genexpr>)
#     11174    0.058    0.000    7.437    0.001 indexing.py:247(_convert_tuple)
#     16955    0.008    0.000    0.020    0.000 indexing.py:2475(is_nested_tuple)
#     68596    0.058    0.000    0.192    0.000 indexing.py:2488(is_label_like)
#     11174    0.037    0.000    0.183    0.000 indexing.py:2565(_can_do_equal_len)
#     50865    0.116    0.000    0.475    0.000 indexing.py:270(_convert_scalar_indexer)
#     11174    0.002    0.000    0.002    0.000 indexing.py:281(_has_valid_setitem_indexer)
#     11174    0.264    0.000    8.271    0.001 indexing.py:313(_setitem_with_indexer)
#     11174    0.071    0.000    4.097    0.000 indexing.py:472(setter)
#     11174    0.139    0.000    2.942    0.000 indexing.py:655(_align_series)
#     22348    0.012    0.000    0.023    0.000 indexing.py:683(ravel)
#     11174    0.015    0.000    0.025    0.000 indexing.py:688(<listcomp>)
#     33522    0.014    0.000    0.052    0.000 indexing.py:705(<genexpr>)
#     34298    0.149    0.000   25.570    0.001 indexing.py:803(_getitem_tuple)
#     11562    0.021    0.000    0.256    0.000 indexing.py:826(_multi_take_opportunity)
#     34686    0.013    0.000    0.046    0.000 indexing.py:841(<genexpr>)
#     23124    0.011    0.000    0.172    0.000 indexing.py:845(<genexpr>)
#     17343    0.003    0.000    0.003    0.000 indexing.py:873(_convert_for_reindex)
#     34298    0.272    0.000    8.196    0.000 indexing.py:901(_getitem_lowerdim)
#    144407    0.068    0.000    0.517    0.000 inference.py:120(is_iterator)
#    149236    0.072    0.000    0.277    0.000 inference.py:246(is_array_like)
#     91038    0.135    0.000    0.298    0.000 inference.py:327(is_dict_like)
#    182264    0.055    0.000    0.124    0.000 inference.py:353(<genexpr>)
#   1016687    0.371    0.000    0.523    0.000 inference.py:386(is_hashable)
#    111740    0.092    0.000    0.155    0.000 inference.py:423(is_sequence)
#     90944    0.030    0.000    0.039    0.000 inspect.py:72(isclass)
#     17331    0.295    0.000    3.450    0.000 managers.py:1031(set)
#     11174    0.008    0.000    0.008    0.000 managers.py:1060(value_getitem)
#      6157    0.091    0.000    2.560    0.000 managers.py:1158(insert)
#     35062    0.156    0.000   10.048    0.000 managers.py:1224(reindex_indexer)
#     93430    0.305    0.000    6.662    0.000 managers.py:126(__init__)
#     11938    0.039    0.000    2.286    0.000 managers.py:1260(<listcomp>)
#     23124    0.363    0.000    5.120    0.000 managers.py:1274(_slice_take_blocks_ax0)
#     93430    0.097    0.000    0.190    0.000 managers.py:132(<listcomp>)
#     17719    0.152    0.000    6.664    0.000 managers.py:1376(take)
#    514424    1.259    0.000    7.144    0.000 managers.py:1470(__init__)
#   1668778    0.327    0.000    0.327    0.000 managers.py:1523(_block)
#    193250    0.048    0.000    0.048    0.000 managers.py:1549(index)
#       188    0.001    0.000    0.005    0.000 managers.py:1553(convert)
#   1242210    0.684    0.000    1.164    0.000 managers.py:1558(dtype)
#    130999    0.092    0.000    0.143    0.000 managers.py:1582(external_values)
#    284395    0.189    0.000    0.295    0.000 managers.py:1585(internal_values)
#     11174    0.010    0.000    0.022    0.000 managers.py:1588(formatting_values)
#    102306    0.015    0.000    0.015    0.000 managers.py:1600(is_consolidated)
#    408848    0.054    0.000    0.054    0.000 managers.py:1606(_consolidate_inplace)
#    326438    0.487    0.000    1.379    0.000 managers.py:167(shape)
#    979314    0.238    0.000    0.892    0.000 managers.py:169(<genexpr>)
#        94    0.000    0.000    0.024    0.000 managers.py:1691(create_block_manager_from_arrays)
#    411336    0.149    0.000    0.193    0.000 managers.py:171(ndim)
#        94    0.002    0.000    0.016    0.000 managers.py:1726(form_blocks)
#     11562    0.027    0.000    0.064    0.000 managers.py:175(set_axis)
#        94    0.001    0.000    0.008    0.000 managers.py:1837(_multi_blockify)
#       188    0.000    0.000    0.000    0.000 managers.py:1841(<lambda>)
#        94    0.001    0.000    0.002    0.000 managers.py:1854(_stack_arrays)
#       188    0.000    0.000    0.001    0.000 managers.py:1857(_asarray_compat)
#        94    0.000    0.000    0.000    0.000 managers.py:1863(_shape_compat)
#      5781    0.020    0.000    2.169    0.000 managers.py:188(rename_axis)
#      5781    0.056    0.000    1.133    0.000 managers.py:1901(_consolidate)
#     62604    0.029    0.000    0.383    0.000 managers.py:1907(<lambda>)
#      5781    0.024    0.000    1.012    0.000 managers.py:1973(_transform_index)
#      5781    0.008    0.000    0.011    0.000 managers.py:1991(<listcomp>)
#      6157    0.041    0.000    0.343    0.000 managers.py:1995(_fast_count_smallints)
#     23124    0.054    0.000    0.103    0.000 managers.py:2002(_preprocess_slice_or_indexer)
#      5781    0.111    0.000    6.894    0.001 managers.py:2020(concatenate_block_managers)
#     34686    0.049    0.000    0.097    0.000 managers.py:203(_is_single_block)
#      5781    0.011    0.000    0.326    0.000 managers.py:2033(<listcomp>)
#     99211    1.227    0.000    3.282    0.000 managers.py:216(_rebuild_blknos_and_blklocs)
#    439452    0.106    0.000    0.106    0.000 managers.py:236(items)
#     34380    0.022    0.000    0.060    0.000 managers.py:325(__len__)
#     52499    0.175    0.000    0.671    0.000 managers.py:340(_verify_integrity)
#    167179    0.070    0.000    0.123    0.000 managers.py:342(<genexpr>)
#    239574    1.267    0.000   14.125    0.000 managers.py:353(apply)
#    239574    0.128    0.000    0.224    0.000 managers.py:418(<dictcomp>)
#     11174    0.015    0.000    1.707    0.000 managers.py:559(setitem)
# ...
#     11844    0.003    0.000    0.003    0.000 numeric.py:86(_zeros_like_dispatcher)
#     11844    0.027    0.000    0.116    0.000 numeric.py:90(zeros_like)
#   1223268    0.574    0.000    0.878    0.000 numerictypes.py:293(issubclass_)
#    611634    0.574    0.000    1.508    0.000 numerictypes.py:365(issubdtype)
#     51794    0.074    0.000    0.095    0.000 numerictypes.py:578(_can_coerce_all)
#     49256    0.012    0.000    0.012    0.000 numerictypes.py:587(<listcomp>)
#     25897    0.057    0.000    0.201    0.000 numerictypes.py:602(find_common_type)
#     25897    0.045    0.000    0.045    0.000 numerictypes.py:654(<listcomp>)
#     25897    0.004    0.000    0.004    0.000 numerictypes.py:655(<listcomp>)
#     45848    0.096    0.000    0.427    0.000 numpy_.py:122(__init__)
#     45848    0.037    0.000    0.098    0.000 numpy_.py:165(__array__)
#     45848    0.191    0.000    0.322    0.000 numpy_.py:39(__init__)
#      5875    0.011    0.000    0.012    0.000 ops.py:131(__init__)
#     11562    0.024    0.000    0.080    0.000 ops.py:142(shape)
#     34686    0.015    0.000    0.056    0.000 ops.py:144(<genexpr>)
#      5875    0.004    0.000    0.006    0.000 ops.py:262(names)
#      5875    0.002    0.000    0.002    0.000 ops.py:264(<listcomp>)
#      5875    0.013    0.000    5.154    0.001 ops.py:294(group_info)
#      5875    0.032    0.000    5.139    0.001 ops.py:311(_get_compressed_labels)
#      5875    0.013    0.000    4.027    0.001 ops.py:312(<listcomp>)
#      5875    0.012    0.000    6.080    0.001 ops.py:320(ngroups)
#      5781    0.021    0.000    5.367    0.001 ops.py:324(recons_labels)
#      5781    0.001    0.000    0.001    0.000 ops.py:327(<genexpr>)
#      5875    0.034    0.000    6.048    0.001 ops.py:330(result_index)
#      5781    0.018    0.000    0.027    0.000 ops.py:336(<listcomp>)
#     11844    0.052    0.000    0.209    0.000 ops.py:406(_get_cython_function)
#     11844    0.020    0.000    0.065    0.000 ops.py:410(get_func)
#      5969    0.150    0.000    7.240    0.001 ops.py:453(_cython_operation)
#      5969    0.016    0.000    7.256    0.001 ops.py:594(aggregate)
#      5969    0.100    0.000    0.255    0.000 ops.py:602(_aggregate)
#     22348    0.048    0.000    0.080    0.000 os.py:674(__getitem__)
#     22348    0.019    0.000    0.032    0.000 os.py:752(encode)
#     11174    0.120    0.000    0.301    0.000 printing.py:12(adjoin)
#     78218    0.127    0.000    0.477    0.000 printing.py:153(pprint_thing)
#     78218    0.176    0.000    0.216    0.000 printing.py:188(as_escaped_unicode)
#     11174    0.013    0.000    0.049    0.000 printing.py:33(<listcomp>)
#     44696    0.030    0.000    0.135    0.000 printing.py:47(justify)
#     33522    0.042    0.000    0.074    0.000 printing.py:52(<listcomp>)
#     11174    0.018    0.000    0.031    0.000 printing.py:56(<listcomp>)
#     78218    0.022    0.000    0.036    0.000 printing.py:59(_join_unicode)
#      5781    0.013    0.000    0.020    0.000 range.py:148(_simple_new)
#      5781    0.001    0.000    0.001    0.000 range.py:170(_validate_dtype)
#     11562    0.006    0.000    0.008    0.000 range.py:655(__len__)
#      5781    0.030    0.000    0.067    0.000 range.py:83(__new__)
#     11174    0.007    0.000    0.007    0.000 series.py:1033(axes)
#     11174    0.107    0.000    5.830    0.001 series.py:1594(__repr__)
#     11174    0.055    0.000    5.142    0.000 series.py:1624(to_string)
#    503250    2.214    0.000   23.956    0.000 series.py:197(__init__)
#    364904    0.069    0.000    0.069    0.000 series.py:402(_constructor)
#    503250    0.563    0.000    0.814    0.000 series.py:419(_set_axis)
#     90944    0.247    0.000    9.601    0.000 series.py:4329(fillna)
#     22736    0.153    0.000    3.202    0.000 series.py:4430(take)
#    503250    0.178    0.000    0.178    0.000 series.py:446(_set_subtyp)
#   1080991    0.687    0.000    1.194    0.000 series.py:456(name)
#    754274    0.416    0.000    0.618    0.000 series.py:463(name)
#   1242210    0.495    0.000    1.659    0.000 series.py:470(dtype)
#    130999    0.063    0.000    0.205    0.000 series.py:520(values)
#    284395    0.133    0.000    0.428    0.000 series.py:562(_values)
#     11174    0.009    0.000    0.032    0.000 series.py:569(_formatting_values)
#     22818    0.010    0.000    0.062    0.000 series.py:723(__len__)
#     45848    0.085    0.000    1.385    0.000 series.py:889(__array__)
#      5781    0.003    0.000    0.005    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#      5781    0.005    0.000    0.010    0.000 shape_base.py:220(_vhstack_dispatcher)
#      5781    0.015    0.000    0.086    0.000 shape_base.py:224(vstack)
#     23112    0.004    0.000    0.004    0.000 shape_base.py:79(_atleast_2d_dispatcher)
#     23112    0.074    0.000    0.112    0.000 shape_base.py:83(atleast_2d)
#     11174    0.074    0.000    0.236    0.000 shutil.py:1073(get_terminal_size)
#     17343    0.016    0.000    0.016    0.000 sorting.py:127(is_int64_overflow_possible)
#      5781    0.111    0.000    0.141    0.000 sorting.py:135(decons_group_index)
#      5781    0.008    0.000    0.155    0.000 sorting.py:155(decons_obs_group_ids)
#      5781    0.139    0.000    0.275    0.000 sorting.py:22(get_group_index)
#      5781    0.047    0.000    0.762    0.000 sorting.py:355(compress_group_index)
#      5781    0.043    0.000    0.631    0.000 sorting.py:376(_reorder_by_uniques)
#     11656    0.075    0.000    1.144    0.000 sorting.py:396(safe_sort)
#      5781    0.012    0.000    0.013    0.000 sorting.py:50(_int64_cut_off)
#    155569    0.115    0.000    0.197    0.000 sparse.py:223(construct_from_string)
#    347446    0.115    0.000    0.115    0.000 {built-in method __new__ of type object at 0x1047d6288}
#   1898759    0.854    0.000    0.855    0.000 {built-in method _abc._abc_instancecheck}
#     149/9    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#      5587    0.024    0.000    0.024    0.000 {built-in method _operator.add}
#     45472    0.094    0.000    0.094    0.000 {built-in method _operator.and_}
#       564    0.002    0.000    0.002    0.000 {built-in method _operator.mul}
#     11368    0.038    0.000    0.038    0.000 {built-in method _operator.sub}
#     23500    0.020    0.000    0.020    0.000 {built-in method builtins.abs}
#    267581    0.160    0.000    1.234    0.000 {built-in method builtins.all}
#    184322    0.115    0.000    0.689    0.000 {built-in method builtins.any}
#    355704    0.046    0.000    0.046    0.000 {built-in method builtins.callable}
#         1    0.000    0.000  151.456  151.456 {built-in method builtins.exec}
# 28431180/28430992    3.829    0.000    4.506    0.000 {built-in method builtins.getattr}
#   5558781    2.451    0.000    3.090    0.000 {built-in method builtins.hasattr}
#   1363133    0.189    0.000    0.190    0.000 {built-in method builtins.hash}
#     11656    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#  42694057    9.400    0.000   16.383    0.000 {built-in method builtins.isinstance}
#  11544188    1.560    0.000    1.560    0.000 {built-in method builtins.issubclass}
#    122914    0.057    0.000    0.057    0.000 {built-in method builtins.iter}
# 10256335/8460218    1.807    0.000    2.642    0.000 {built-in method builtins.len}
#     87172    0.092    0.000    0.333    0.000 {built-in method builtins.max}
#     62427    0.048    0.000    0.189    0.000 {built-in method builtins.min}
#      5781    0.004    0.000    0.019    0.000 {built-in method builtins.next}
#      5781    0.004    0.000    0.004    0.000 {built-in method builtins.setattr}
#     23124    0.047    0.000    0.253    0.000 {built-in method builtins.sorted}
#     75799    0.073    0.000    0.218    0.000 {built-in method builtins.sum}
#    195831    0.259    0.000    0.259    0.000 {built-in method numpy.arange}
# 1420287/1322434    2.093    0.000    3.488    0.000 {built-in method numpy.array}
# 363250/221498    0.500    0.000    2.608    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      5781    0.004    0.000    0.004    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#    456076    0.777    0.000    0.777    0.000 {built-in method numpy.empty}
#    758996    0.149    0.000    0.149    0.000 {built-in method numpy.geterrobj}
#    379498    0.207    0.000    0.207    0.000 {built-in method numpy.seterrobj}
#     17813    0.026    0.000    0.026    0.000 {built-in method numpy.zeros}
#      5781    0.011    0.000    0.011    0.000 {built-in method pandas._libs.lib.is_bool_array}
#    297098    0.088    0.000    0.088    0.000 {built-in method pandas._libs.missing.checknull}
#      5781    0.042    0.000    0.042    0.000 {built-in method pandas._libs.missing.isnaobj}
#     11174    0.067    0.000    0.067    0.000 {built-in method posix.get_terminal_size}
#    150306    0.017    0.000    0.017    0.000 {function FrozenList.__getitem__ at 0x11a1878c0}
#     25521    0.015    0.000    0.015    0.000 {method 'add' of 'pandas._libs.internals.BlockPlacement' objects}
#     11562    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#     42570    0.030    0.000    0.213    0.000 {method 'all' of 'numpy.ndarray' objects}
#    311216    0.210    0.000    1.411    0.000 {method 'any' of 'numpy.ndarray' objects}
#    749636    0.106    0.000    0.106    0.000 {method 'append' of 'list' objects}
#     34874    0.067    0.000    0.067    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#    122341    0.163    0.000    0.163    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     45848    0.092    0.000    0.092    0.000 {method 'clear' of 'dict' objects}
#     31584    0.007    0.000    0.007    0.000 {method 'copy' of 'dict' objects}
#    299933    0.439    0.000    0.439    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     23124    0.006    0.000    0.006    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     22348    0.011    0.000    0.011    0.000 {method 'encode' of 'str' objects}
#     22442    0.003    0.000    0.003    0.000 {method 'extend' of 'list' objects}
#     34686    0.354    0.000    0.416    0.000 {method 'factorize' of 'pandas._libs.hashtable.Int64Factorizer' objects}
#     11656    0.164    0.000    0.190    0.000 {method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects}
#     11174    0.014    0.000    0.014    0.000 {method 'fileno' of '_io.TextIOWrapper' objects}
#    204297    0.121    0.000    0.121    0.000 {method 'fill' of 'numpy.ndarray' objects}
# 2985322/2825111    2.061    0.000    3.474    0.000 {method 'format' of 'str' objects}
#   1330351    0.287    0.000    0.287    0.000 {method 'get' of 'dict' objects}
#     17343    0.003    0.000    0.003    0.000 {method 'get_count' of 'pandas._libs.hashtable.Int64Factorizer' objects}
#     63685    0.473    0.000    0.601    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#      5781    0.065    0.000    0.078    0.000 {method 'get_labels_groupby' of 'pandas._libs.hashtable.Int64HashTable' objects}
#    327933    0.499    0.000    6.328    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#     11174    0.004    0.000    0.004    0.000 {method 'getvalue' of '_io.StringIO' objects}
#     23124    0.007    0.000    0.007    0.000 {method 'index' of 'list' objects}
#    535839    0.088    0.000    0.088    0.000 {method 'items' of 'dict' objects}
#     89392    0.047    0.000    0.047    0.000 {method 'join' of 'str' objects}
#        94    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#     17531    0.003    0.000    0.003    0.000 {method 'keys' of 'dict' objects}
#    201132    0.031    0.000    0.031    0.000 {method 'ljust' of 'str' objects}
#    155569    0.035    0.000    0.035    0.000 {method 'lower' of 'str' objects}
#    167225    0.154    0.000    0.154    0.000 {method 'match' of 're.Pattern' objects}
#     63661    0.077    0.000    0.077    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#    394551    0.079    0.000    0.079    0.000 {method 'pop' of 'dict' objects}
#     11562    0.009    0.000    0.009    0.000 {method 'pop' of 'list' objects}
#      5781    0.006    0.000    0.006    0.000 {method 'put' of 'numpy.ndarray' objects}
#     66446    0.046    0.000    0.046    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    446258    1.735    0.000    1.735    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    201132    0.030    0.000    0.030    0.000 {method 'replace' of 'str' objects}
#      5781    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     67044    0.013    0.000    0.013    0.000 {method 'rjust' of 'str' objects}
#    283479    0.087    0.000    0.087    0.000 {method 'rpartition' of 'str' objects}
#    155569    0.056    0.000    0.056    0.000 {method 'search' of 're.Pattern' objects}
#     11562    0.017    0.000    0.017    0.000 {method 'sort' of 'numpy.ndarray' objects}
#    245828    0.064    0.000    0.064    0.000 {method 'split' of 'str' objects}
#    490019    0.120    0.000    0.120    0.000 {method 'startswith' of 'str' objects}
#     17343    0.017    0.000    0.168    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      5781    0.005    0.000    0.005    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#    109721    0.139    0.000    0.139    0.000 {method 'take' of 'numpy.ndarray' objects}
#      5781    0.004    0.000    0.004    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#     12314    0.009    0.000    0.009    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#    225587    0.068    0.000    0.068    0.000 {method 'update' of 'dict' objects}
#     17437    0.005    0.000    0.005    0.000 {method 'upper' of 'str' objects}
#        94    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     37177    0.007    0.000    0.007    0.000 {method 'values' of 'dict' objects}
#    625656    0.329    0.000    0.329    0.000 {method 'view' of 'numpy.ndarray' objects}
#     11174    0.004    0.000    0.004    0.000 {method 'write' of '_io.StringIO' objects}
#      5875    0.021    0.000    0.021    0.000 {pandas._libs.algos.ensure_float64}
#    274433    0.127    0.000    0.127    0.000 {pandas._libs.algos.ensure_int64}
#     46248    0.044    0.000    0.044    0.000 {pandas._libs.algos.ensure_int8}
#    202499    0.036    0.000    0.036    0.000 {pandas._libs.algos.ensure_platform_int}
#     98371    0.519    0.000    0.519    0.000 {pandas._libs.algos.take_1d_int64_int64}
#     28905    0.154    0.000    0.154    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#     17719    0.098    0.000    0.098    0.000 {pandas._libs.algos.take_2d_axis0_object_object}
#      7379    0.054    0.000    0.054    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#     35062    0.223    0.000    0.223    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#     40079    0.032    0.000    0.032    0.000 {pandas._libs.internals.get_blkno_placements}
#      5781    0.259    0.000    1.052    0.000 {pandas._libs.join.left_outer_join}
#     17437    0.232    0.000    0.477    0.000 {pandas._libs.lib.clean_index_list}
#      5781    0.041    0.000    0.041    0.000 {pandas._libs.lib.get_reverse_indexer}
#    186020    1.124    0.000    1.723    0.000 {pandas._libs.lib.infer_dtype}
#    274478    0.044    0.000    0.044    0.000 {pandas._libs.lib.is_bool}
#    387033    0.072    0.000    0.072    0.000 {pandas._libs.lib.is_float}
#    540086    0.087    0.000    0.087    0.000 {pandas._libs.lib.is_integer}
#   1135676    0.775    0.000    1.595    0.000 {pandas._libs.lib.is_list_like}
#   1074389    1.009    0.000    1.572    0.000 {pandas._libs.lib.is_scalar}
#    275758    0.054    0.000    0.054    0.000 {pandas._libs.lib.item_from_zerodim}
#     11174    0.305    0.000    0.318    0.000 {pandas._libs.lib.map_infer}
#    281869    0.220    0.000    0.406    0.000 {pandas._libs.lib.values_from_object}
#     34674    0.424    0.000    0.424    0.000 {pandas._libs.ops.scalar_compare}

# %%
cProfile.run(
    "analyze_empty_acreage(future_yields, 'soy')"
)

# %% [markdown]
# # 4. Test these new functions out on Ishan's examples

# %%
# the list of crops we're working with
crops = ['soy', 'rice']

# Initial conditions
yields = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'yield': [10, 20, 15, 20, 10, 15]
})

calories = pd.DataFrame({
    'crop': ['soy', 'rice'],
    'calories': [25, 15]
})

acreage = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'acres_planted': [40, 70, 0, 60, 30, 0],
    'total_acres': [100, 100, 100, 100, 100, 100]
})

# may want to turn the lines that return the merged dataframe into a function that
# standardizes datasets--tbd
present_yields = (yields
          .merge(calories, how='left', on='crop')
          .merge(acreage, how='left', on=['crop', 'geo1_id', 'geo0_id'])
         )
    
present_yields['calorie_yield'] = present_yields['yield'] * present_yields['calories']

# %%
# Climate shocks
# This will eventually be the real projections from the ag sector.
# Before then, we'll use random draws.
# Just use Ishan's numbers for now.

yield_shocks = pd.DataFrame({
    'geo0_id': [1, 1, 1, 1, 1, 1],
    'geo1_id': [1, 2, 3, 1, 2, 3],
    'crop': ['soy', 'soy', 'soy', 'rice', 'rice', 'rice'],
    'yield_shock': [0.5, 0.8, 1, 0.9, 0.6, 1]
})

future_yields = (yield_shocks
                 .merge(present_yields, how='outer', on=['geo0_id', 'geo1_id', 'crop'])
                )
future_yields['future_yield'] = future_yields['yield'] * future_yields['yield_shock']

# replace the yield column with the future yield column and re-calculate moments
future_yields['yield'] = future_yields['future_yield']
future_yields.drop('future_yield', inplace=True, axis=1)

# %%
present_yields

# %%
present_yields.loc[present_yields['crop'] == 'soy', 'acres_planted']

# %%
x

# %%
# function for making barplots of raw data
def make_barplot(col, ylabel, df=present_yields):
    labels = [1, 2, 3]
    x = np.arange(len(labels))
    width = 0.35
    
    fig, ax = plt.subplots()
    bar1 = ax.bar(
        x + width/2,
        df.loc[df['crop'] == 'rice', col],
        width,
        label = 'rice'
    )

    bar2 = ax.bar(
        x - width/2, 
        df.loc[df['crop'] == 'soy', col],
        width,
        label = 'soy'
    )

    ax.set_ylabel(ylabel)
    ax.set_xlabel('Field')
    ax.set_xticks(x)
    ax.legend()
    return plt.show()

# %%
# plot total current acreage
make_barplot('acres_planted', 'Acres planted')

# %%
# plot current yields
make_barplot('yield', 'Yield')

# %%
# plot calories per acre
make_barplot('calorie_yield', 'Calories')

# %% [markdown]
# Given the above raw data, our expected values for phi are 0.9 for soy and 0.909 for rice. Does my code give us this?

# %%
calculate_phi(present_yields, 'soy')

# %%
calculate_phi(present_yields, 'rice')

# %%
# plot climate shock ratios
make_barplot(df=future_yields, col='yield_shock', ylabel='Future Yield/Current Yield')

# %% [markdown]
# # Benchmark

# %%
import timeit

# %%
# gamma calculation
timeit.timeit("lambda: calculate_gamma(present_yields)", number=10000)
# Out:
# 0.0006674389987892937

# %%
# analyze_empty_acreage
timeit.timeit("lambda: analyze_empty_acreage(present_yields, 'soy')")
# Out:
# 0.0628344280012243

# %%
# reallocate_crops
empty_max_yield, used_min_yield, empty_max_id, used_min_id = (
    analyze_empty_acreage(present_yields, 'soy'))

timeit.timeit("labmda: reallocate_crops(present_yields, 'soy', empty_max_yield, used_min_yield, empty_max_id, used_min_id)", number=10000)
# Out:
# 8.828700083540753e-05

# %%
timeit.timeit("lambda: calculate_phi(present_yields, 'soy')")
# Out:
# 0.062093491998894024

# %%
calculate_distances(present_yields, future_yields, ['soy', 'rice'])
# Out:
# [0.0, 0.1325581395348837, 0.08556149732620322]

# %%
match_moments(present_yields, future_yields, ['soy', 'rice'])
# Out:
#    geo0_id  geo1_id  crop  yield_shock  yield  calories  acres_planted  \
# 0        1        1   soy          0.5    5.0        25             17
# 1        1        2   soy          0.8   16.0        25             87
# 2        1        3   soy          1.0   15.0        25              6
# 3        1        1  rice          0.9   18.0        15             76
# 4        1        2  rice          0.6    6.0        15             13
# 5        1        3  rice          1.0   15.0        15              1
#
#    total_acres  calorie_yield
# 0          100            250
# 1          100            500
# 2          100            375
# 3          100            300
# 4          100            150
# 5          100            225

# %%
# %timeit -n 1 match_moments(present_yields, future_yields, ['soy', 'rice'])
# Out:
# 1min 38s ± 2.96 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit -n 100000 calculate_phi(present_yields, 'soy')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
# -> 5191             object.__getattribute__(self, name)
#    5192             return object.__setattr__(self, name, value)
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/series.py in name(self)
#     460         """
# --> 461         return self._name
#     462
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#
# AttributeError: 'Series' object has no attribute '_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-c743da338f0a> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', "-n 100000 calculate_phi(present_yields, 'soy')")
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1162                     break
#    1163
# -> 1164         all_runs = timer.repeat(repeat, number)
#    1165         best = min(all_runs) / number
#    1166         worst = max(all_runs) / number
#
# ~/miniconda3/envs/risingverse/lib/python3.7/timeit.py in repeat(self, repeat, number)
#     202         r = []
#     203         for i in range(repeat):
# --> 204             t = self.timeit(number)
#     205             r.append(t)
#     206         return r
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-88-e74923fa34cd> in calculate_phi(df, crop)
#      39         # recalculate empty acreage
#      40         empty_max_yield, used_min_yield, empty_max_id, used_min_id = (
# ---> 41             analyze_empty_acreage(df, crop)
#      42         )
#      43
#
# <ipython-input-72-731580b70de2> in analyze_empty_acreage(df, crop)
#      19     total_acres = (df[['geo0_id', 'geo1_id', 'acres_planted']]
#      20                    .copy()
# ---> 21                    .groupby(['geo0_id', 'geo1_id'])
#      22                    .sum()
#      23                    .rename(columns={'acres_planted':'total_acres_planted'})
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     614                 if validate:
#     615                     obj._check_label_or_level_ambiguity(gpr)
# --> 616                 in_axis, name, gpr = True, gpr, obj[gpr]
#     617                 exclusions.append(name)
#     618             elif obj._is_level_reference(gpr):
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2971                 if self.columns.nlevels > 1:
#    2972                     return self._getitem_multilevel(key)
# -> 2973                 return self._get_item_cache(key)
#    2974
#    2975         # Do we have a slicer (on rows)?
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3269         if res is None:
#    3270             values = self._data.get(item)
# -> 3271             res = self._box_item_values(item, values)
#    3272             cache[item] = res
#    3273             res._set_as_cached(item, self)
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/frame.py in _box_item_values(self, key, values)
#    3462             return self._constructor(values.T, columns=items, index=self.index)
#    3463         else:
# -> 3464             return self._box_col_values(values, items)
#    3465
#    3466     def _box_col_values(self, values, items):
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/frame.py in _box_col_values(self, values, items)
#    3469         """
#    3470         klass = self._constructor_sliced
# -> 3471         return klass(values, index=self.index, name=items, fastpath=True)
#    3472
#    3473     def __setitem__(self, key, value):
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     318         generic.NDFrame.__init__(self, data, fastpath=True)
#     319
# --> 320         self.name = name
#     321         self._set_axis(0, index, fastpath=True)
#     322
#
# ~/miniconda3/envs/risingverse/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5189
#    5190         try:
# -> 5191             object.__getattribute__(self, name)
#    5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#
# KeyboardInterrupt:
